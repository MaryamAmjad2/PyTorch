# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.13.0+cpu

# %%
x=torch.tensor([1,2,3])
y=torch.zeros([3,2])
z=torch.rand(2,2)
print(x.type)
print(y[2,1])
print(x[0])
# Out:
# <built-in method type of Tensor object at 0x0000013EB32E3980>
# tensor(0.)
# tensor(1)

# %%
import  numpy as  np
arr=np.array([1,2,3,4,5])
arr_tensor=torch.tensor(arr)
arr_tensor
# Out:
# tensor([1, 2, 3, 4, 5], dtype=torch.int32)
